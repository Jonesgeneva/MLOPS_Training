# %%
import pandas as pd

# %%
df = pd.read_csv('smart_infrastructure_risk_dataset.csv')
df
# Out:
#      complaint_id                                     complaint_text  \
# 0               1  Pothole on Ondipudur highway not repaired for ...
# 1               2  Structural crack near Kovaipudur flyover needs...
# 2               3  Storm drain clogged at Thudiyalur junction cre...
# 3               4  Electric sparks from transformer near Perur ju...
# 4               5  Bridge railings broken near Thudiyalur posing ...
# ..            ...                                                ...
# 995           996  Dangerous pothole near Ganapathy hospital entr...
# 996           997  Cracks on Mettupalayam Road road foundation ca...
# 997           998  Blocked drainage near Sowripalayam causing wat...
# 998           999  Fallen electric pole on Vellalore road blockin...
# 999          1000  Load bearing capacity of Kavundampalayam bridg...
#
#           category severity                       location  \
# 0          pothole     high          Ondipudur, Coimbatore
# ...

# %%
df[['complaint_frequency','damage_size','previous_accidents','repair_delay_days','risk_score']]
# Out:
#      complaint_frequency  damage_size  previous_accidents  repair_delay_days  \
# 0                     40         7.17                   9                126
# 1                     30         5.36                   8                 55
# 2                     30         9.17                  15                162
# 3                     41         8.16                  13                100
# 4                     11         3.01                   0                 17
# ..                   ...          ...                 ...                ...
# 995                    8         1.26                   3                  0
# 996                   33         8.74                   6                108
# 997                   12         2.59                   3                 23
# 998                   15         2.38                   3                 33
# 999                   18         4.24                   2                104
#
#      risk_score
# 0         73.06
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['repair_delay_days'],df['risk_score'])

# %%
x = df[['complaint_frequency','damage_size','previous_accidents','repair_delay_days']]
y = df['risk_score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
X_train
# Out:
#      complaint_frequency  damage_size  previous_accidents  repair_delay_days
# 793                    5         1.11                   3                 13
# 454                   31         3.91                   3                103
# 105                   44         6.57                  11                134
# 14                    32         8.29                   9                142
# 760                   30         3.31                   4                 59
# ..                   ...          ...                 ...                ...
# 459                   32         8.75                  11                100
# 631                   12         1.67                   1                 27
# 641                   11         2.28                   2                 18
# 707                   48         7.30                  15                175
# 685                   45         6.47                   9                136
#
# [700 rows x 4 columns]

# %%
X_test
# Out:
#      complaint_frequency  damage_size  previous_accidents  repair_delay_days
# 520                   39         7.59                  10                150
# 59                    14         4.02                   3                107
# 423                   15         6.53                   6                 76
# 838                    1         0.85                   2                 37
# 678                   41         6.88                  11                167
# ..                   ...          ...                 ...                ...
# 322                   35         8.02                  12                143
# 139                   43         6.29                  12                134
# 401                   22         3.41                   2                 90
# 952                   10         1.79                   3                 11
# 994                   13         0.94                   0                  6
#
# [300 rows x 4 columns]

# %%
y_train
# Out:
# 793    13.31
# 454    52.89
# 105    71.93
# 14     77.81
# 760    40.45
#        ...
# 459    76.69
# 631    23.29
# 641    17.04
# 707    84.58
# 685    70.43
# Name: risk_score, Length: 700, dtype: float64

# %%
y_test
# Out:
# 520    71.61
# 59     38.35
# 423    45.12
# 838    11.62
# 678    80.20
#        ...
# 322    79.88
# 139    80.40
# 401    38.19
# 952    21.55
# 994    10.88
# Name: risk_score, Length: 300, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      complaint_frequency  damage_size  previous_accidents  repair_delay_days
# 520                   39         7.59                  10                150
# 59                    14         4.02                   3                107
# 423                   15         6.53                   6                 76
# 838                    1         0.85                   2                 37
# 678                   41         6.88                  11                167
# ..                   ...          ...                 ...                ...
# 322                   35         8.02                  12                143
# 139                   43         6.29                  12                134
# 401                   22         3.41                   2                 90
# 952                   10         1.79                   3                 11
# 994                   13         0.94                   0                  6
#
# [300 rows x 4 columns]

# %%
model.predict(X_test)
# Out:
# array([77.14056326, 39.01854167, 47.30397378, 13.13883185, 79.65514459,
#        36.324651  , 38.52782923, 78.69717833, 55.44346886, 74.90397506,
#        16.0706708 , 20.61197559, 36.43628239, 14.81117421, 35.74577067,
#        21.35595787, 20.23901681, 17.85682688, 31.87859038, 16.14857538,
#        67.93783763, 68.36936652, 44.42488488, 45.78252986, 16.76171921,
#        76.82983013, 51.88763951, 18.04915974, 41.68324739, 12.95053624,
#        77.69828603, 15.52117939, 83.6039278 , 65.31638331, 75.60795879,
#        80.56352579, 43.65829094, 87.28042997, 48.07224646, 18.27703176,
#        71.82250438, 10.71234707, 85.81342421, 12.89631272, 41.76249028,
#        47.30527703, 51.43670414, 20.93374185, 14.28476143, 51.4435927 ,
#        43.88615907, 44.83531423, 16.86043148, 73.35395019, 15.56736284,
#        40.39691231, 58.39669686, 46.85232141, 15.34419054, 17.95942204,
#        47.36162746, 72.9787845 , 80.81202267, 39.38682155, 36.95253503,
# ...

# %%
y_test
# Out:
# 520    71.61
# 59     38.35
# 423    45.12
# 838    11.62
# 678    80.20
#        ...
# 322    79.88
# 139    80.40
# 401    38.19
# 952    21.55
# 994    10.88
# Name: risk_score, Length: 300, dtype: float64

# %%
clf.score(X_test, y_test)
# Out:
# 0.9805984904818965

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)
X_test
# Out:
#      complaint_frequency  damage_size  previous_accidents  repair_delay_days
# 841                   10         2.22                   3                 17
# 956                   32         8.91                  12                123
# 544                   15         2.25                   1                  6
# 173                    1         1.38                   3                  5
# 759                    7         0.57                   3                 14
# ..                   ...          ...                 ...                ...
# 949                   36         9.13                  14                126
# 802                   29         8.86                   9                109
# 293                   25         4.53                   2                 98
# 414                   32         4.00                   8                 86
# 260                   38         6.63                   7                132
#
# [300 rows x 4 columns]
